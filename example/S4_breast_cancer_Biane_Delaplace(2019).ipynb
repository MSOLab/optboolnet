# %%
from optboolnet.instances import load_bn_in_repo
from optboolnet.launch import control_fixpoint

# %%
bn = load_bn_in_repo("S4")
s = control_fixpoint(bn, max_size=2, target={"p": 1},exclude=["BAX","CYCD1","p"])
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-09-22

# %%
s.as_graph()

# %%
s.as_table()
# Out:
# c:\Users\user\miniconda3\envs\optboolnet\Lib\site-packages\algorecell_types\__init__.py:324: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df = df.applymap(colorize)
# <style type="text/css">
# #T_e3bda th {
#   border-right: 1px solid black;
# }
# #T_e3bda td {
#   border-right: 1px solid black;
#   min-width: 2em;
# }
# #T_e3bda th.col_heading {
#   writing-mode: vertical-lr;
#   transform: rotateZ(180deg);
#   vertical-align: top;
#   border-bottom: 1px solid black;
#   text-orientation: mixed;
# }
# #T_e3bda_row0_col9, #T_e3bda_row3_col5, #T_e3bda_row4_col8, #T_e3bda_row5_col5, #T_e3bda_row6_col2 {
#   color: black;
#   background-color: lime;
# }
# #T_e3bda_row1_col7, #T_e3bda_row2_col6, #T_e3bda_row3_col4, #T_e3bda_row4_col3, #T_e3bda_row5_col3, #T_e3bda_row7_col1, #T_e3bda_row8_col0 {
#   color: black;
#   background-color: red;
# }
# </style>
# <table id="T_e3bda">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
s.perturbations()
# Out:
# {({'AKT': 1},),
#  ({'BCL_2': 1},),
#  ({'BRCA1': 0},),
#  ({'ERK1_2': 1, 'GSK3B': 0},),
#  ({'GSK3B': 0, 'EGFR': 1},),
#  ({'MDM2': 1},),
#  ({'PI3K': 1},),
#  ({'PTEN': 0, 'EGFR': 1},),
#  ({'TP53': 0},)}
