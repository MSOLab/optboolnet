# %%
from optboolnet.instances import load_bn_in_repo
from optboolnet.launch import control_sync_attr_separation

# %%
bn = load_bn_in_repo("S2")
s = control_sync_attr_separation(bn, max_size=7, target={"p": 1},exclude=["Prolif","Apop","p"], max_attr_length=15)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-09-22

# %%
s.as_graph()

# %%
s.as_table()
# Out:
# c:\Users\user\miniconda3\envs\optboolnet\Lib\site-packages\algorecell_types\__init__.py:324: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df = df.applymap(colorize)
# <style type="text/css">
# #T_75b40 th {
#   border-right: 1px solid black;
# }
# #T_75b40 td {
#   border-right: 1px solid black;
#   min-width: 2em;
# }
# #T_75b40 th.col_heading {
#   writing-mode: vertical-lr;
#   transform: rotateZ(180deg);
#   vertical-align: top;
#   border-bottom: 1px solid black;
#   text-orientation: mixed;
# }
# ...

# %%
s.perturbations()
# Out:
# {({'AKT': 1, 'MYC': 1, 'Hypoxia': 0, 'DNA_Damage': 0},),
#  ({'AKT': 1, 'MYC': 1, 'Hypoxia': 0, 'MDM2': 1},),
#  ({'Cyc_Cdk': 1, 'AKT': 1},),
#  ({'Cyc_Cdk': 1, 'BAD': 0},),
#  ({'Cyc_Cdk': 1, 'BAX': 0},),
#  ({'Cyc_Cdk': 1, 'DNA_Damage': 0},),
#  ({'Cyc_Cdk': 1, 'MDM2': 1},),
#  ({'Cyc_Cdk': 1, 'PTEN': 0, 'GrowthFactor': 1},),
#  ({'MYC': 1, 'Hypoxia': 0, 'FOXO': 0, 'DNA_Damage': 0},),
#  ({'MYC': 1, 'Hypoxia': 0, 'MDM2': 1, 'FOXO': 0},),
#  ({'MYC': 1, 'Hypoxia': 0, 'PTEN': 0, 'GrowthFactor': 1, 'DNA_Damage': 0},),
#  ({'MYC': 1, 'Hypoxia': 0, 'PTEN': 0, 'MDM2': 1, 'GrowthFactor': 1},),
#  ({'OverPop': 0, 'AKT': 1, 'Hypoxia': 0, 'DNA_Damage': 0},),
#  ({'OverPop': 0, 'AKT': 1, 'Hypoxia': 0, 'MDM2': 1},),
#  ({'OverPop': 0,
#    'Hypoxia': 0,
#    'GrowthFactor': 1,
#    'FOXO': 0,
#    'DNA_Damage': 0},),
#  ({'OverPop': 0, 'Hypoxia': 0, 'MDM2': 1, 'GrowthFactor': 1, 'FOXO': 0},),
#  ({'OverPop': 0,
#    'Hypoxia': 0,
#    'PTEN': 0,
#    'GrowthFactor': 1,
# ...
