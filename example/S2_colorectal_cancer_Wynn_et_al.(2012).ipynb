# %%
from optboolnet.instances import load_bn_in_repo
from optboolnet.algorithm import BendersAttractorControl
# Out:
# <script type="text/javascript" id="colomoto-setup-4239816" class="to-be-removed">
#         if (typeof Jupyter != 'undefined') {
#
# function detect_import(cell, module) {
#     var code = cell.get_text();
#     code = code.replace(/\\\n/g, "");
#     var lines = code.split("\n");
#     var r_simple = new RegExp("^("+module+")$");
#     var r_alias = new RegExp("^"+module+"\\s+as\\s+(\\w+)$");
#     for (var i = 0; i < lines.length; ++i) {
#         if (/^import\s/.test(lines[i])) {
#             code = lines[i].substr(7);
#             var parts = code.split(",")
#             for (var j = 0; j < parts.length; ++j) {
#                 code = parts[j].trim();
#                 var m = code.match(r_simple);
#                 if (!m) {
#                     m = code.match(r_alias);
#                 }
#                 if (m) {
#                     return m[1];
#                 }
#             }
#         }
#     }
#     return module;
# }
#
# ...

# %%
bn = load_bn_in_repo("S2")
s = BendersAttractorControl("", bn).get_control_strategies(
    max_control_size=7, max_length=15, solve_separation=True
)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-01-28

# %%
s.as_graph()

# %%
s.as_table()
# Out:
# /home/kalebmoon07/anaconda3/envs/boolnet/lib/python3.10/site-packages/algorecell_types-1.0-py3.10.egg/algorecell_types/__init__.py:324: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df = df.applymap(colorize)
# <style type="text/css">
# #T_af45f th {
#   border-right: 1px solid black;
# }
# #T_af45f td {
#   border-right: 1px solid black;
#   min-width: 2em;
# }
# #T_af45f th.col_heading {
#   writing-mode: vertical-lr;
#   transform: rotateZ(180deg);
#   vertical-align: top;
#   border-bottom: 1px solid black;
#   text-orientation: mixed;
# }
# ...

# %%
s.perturbations()
# Out:
# {({'AKT': 1, 'Cyc_Cdk': 1},),
#  ({'AKT': 1, 'MDM2': 1, 'OverPop': 0, 'Hypoxia': 0},),
#  ({'AKT': 1, 'OverPop': 0, 'Hypoxia': 0, 'DNA_Damage': 0},),
#  ({'AKT': 1, 'P53': 0, 'OverPop': 0, 'Hypoxia': 0},),
#  ({'Cyc_Cdk': 1, 'BAD': 0},),
#  ({'Cyc_Cdk': 1, 'BAX': 0},),
#  ({'Cyc_Cdk': 1, 'DNA_Damage': 0},),
#  ({'Cyc_Cdk': 1, 'MDM2': 1},),
#  ({'Cyc_Cdk': 1, 'P53': 0},),
#  ({'Cyc_Cdk': 1, 'PTEN': 0, 'GrowthFactor': 1},),
#  ({'FOXO': 0, 'MDM2': 1, 'OverPop': 0, 'Hypoxia': 0, 'GrowthFactor': 1},),
#  ({'FOXO': 0,
#    'OverPop': 0,
#    'Hypoxia': 0,
#    'GrowthFactor': 1,
#    'DNA_Damage': 0},),
#  ({'FOXO': 0, 'P53': 0, 'OverPop': 0, 'Hypoxia': 0, 'GrowthFactor': 1},),
#  ({'MDM2': 1, 'PTEN': 0, 'OverPop': 0, 'Hypoxia': 0, 'GrowthFactor': 1},),
#  ({'MYC': 1, 'AKT': 1, 'Hypoxia': 0, 'DNA_Damage': 0},),
#  ({'MYC': 1, 'AKT': 1, 'MDM2': 1, 'Hypoxia': 0},),
#  ({'MYC': 1, 'AKT': 1, 'P53': 0, 'Hypoxia': 0},),
#  ({'MYC': 1, 'FOXO': 0, 'Hypoxia': 0, 'DNA_Damage': 0},),
# ...
