# %%
from optboolnet.instances import load_bn_in_repo
from optboolnet.launch import control_sync_attr_separation

# %%
bn = load_bn_in_repo("S1")
s = control_sync_attr_separation(bn, max_size=7, target={"p": 1},exclude=["pRB","p"], max_attr_length=15)
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2026-09-22

# %%
s.as_graph()

# %%
s.as_table()
# Out:
# c:\Users\user\miniconda3\envs\optboolnet\Lib\site-packages\algorecell_types\__init__.py:324: FutureWarning: Styler.applymap has been deprecated. Use Styler.map instead.
#   df = df.applymap(colorize)
# <style type="text/css">
# #T_99df7 th {
#   border-right: 1px solid black;
# }
# #T_99df7 td {
#   border-right: 1px solid black;
#   min-width: 2em;
# }
# #T_99df7 th.col_heading {
#   writing-mode: vertical-lr;
#   transform: rotateZ(180deg);
#   vertical-align: top;
#   border-bottom: 1px solid black;
#   text-orientation: mixed;
# }
# #T_99df7_row0_col14, #T_99df7_row1_col13 {
#   color: black;
#   background-color: red;
# }
# ...

# %%
s.perturbations()
# Out:
# {({'AKT1': 0, 'MEK1': 0},),
#  ({'CDK4': 0},),
#  ({'CDK6': 0},),
#  ({'Cyclin_D1': 0},),
#  ({'EGF': 0, 'IGF1R': 0},),
#  ({'ERBB1': 0, 'ERBB2_3': 0, 'IGF1R': 0},),
#  ({'ERBB1': 0, 'ERBB3': 0, 'IGF1R': 0},),
#  ({'ERBB2': 0, 'ERBB1': 0, 'IGF1R': 0},),
#  ({'ER_a': 0},),
#  ({'c_MYC': 0},),
#  ({'p21': 1},),
#  ({'p27': 1},)}
